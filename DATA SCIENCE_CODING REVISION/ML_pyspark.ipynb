# %% [markdown]
# #### CRISP-DM
# - Business Understanding
# - Data Understanding : Exploratory Data Analysis
# - Data Preparation : Data cleaning, normalization, Feature Engineering etc
# - Model Selection
# - Model Evaluation
# - Model Deployment
# - Monitoring

# %%
# !pip install findspark
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install pyspark
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Spark libraries and dependencies
from pyspark.sql.types import StructType, StructField, IntegerType,DoubleType, StringType
from pyspark.sql.functions import min, max, mean, variance, stddev
from pyspark.sql import functions as F

from pyspark.sql import SparkSession

# %%
x = pd.read

# %%
spark = SparkSession.builder.appName('Big Data Assessment 2').config('Pyspark', 'AI').getOrCreate()

# %%
spark = SparkSession.builder.appName("Financial_modelling_forecast").config("Pyspark", "AI").getOrCreate()

# %%
df1 = spark.read.csv('financial_data_1000_records.csv', header = True, inferSchema = True)
df1.show(5)

# %%
df1 = spark.read_csv("financial_data_1000_records.csv", header = True, inferSchema = True)
df1.show()
